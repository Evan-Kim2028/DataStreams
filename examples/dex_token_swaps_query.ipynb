# %%
from datastreams.datastream import DataStream

import pandas as pd

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# %%
endpointList = [
    'https://api.thegraph.com/subgraphs/name/messari/sushiswap-ethereum', 
    'https://api.thegraph.com/subgraphs/name/messari/balancer-v2-ethereum',
    'https://api.thegraph.com/subgraphs/name/messari/curve-finance-ethereum',
    'https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2', # https://thegraph.com/hosted-service/subgraph/uniswap/uniswap-v2 # NON-MESSARi SUBGRAPH
    'https://api.thegraph.com/subgraphs/name/messari/uniswap-v3-ethereum',
    'https://api.thegraph.com/subgraphs/name/messari/saddle-finance-ethereum'
    ]

# %%
ds = DataStream(endpointList)

# endpoints loaded into DataStream
print(f' the endpoints are: {ds.streamerDict.keys()}')
# Out:
#  the endpoints are: dict_keys(['sushiswap-ethereum', 'balancer-v2-ethereum', 'curve-finance-ethereum', 'uniswap-v2', 'uniswap-v3-ethereum', 'saddle-finance-ethereum'])

# %%
common_keys = ds.getCommonQueryKeys()
print(f'common_keys: {common_keys}') # check which keys are shared between all endpoints
# Out:
# common_keys: ['swaps', 'tokens']

# %%
df_list = ds.querySubgraphs(ds.streamerDict, 'swaps', query_size=100)
# Out:
# querying https://api.thegraph.com/subgraphs/name/messari/sushiswap-ethereum for swaps...
# FIELD - swaps
# querying https://api.thegraph.com/subgraphs/name/messari/balancer-v2-ethereum for swaps...
# FIELD - swaps
# querying https://api.thegraph.com/subgraphs/name/messari/curve-finance-ethereum for swaps...
# FIELD - swaps
# querying https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2 for swaps...
# FIELD - swaps
# querying https://api.thegraph.com/subgraphs/name/messari/uniswap-v3-ethereum for swaps...
# FIELD - swaps
# querying https://api.thegraph.com/subgraphs/name/messari/saddle-finance-ethereum for swaps...
# FIELD - swaps

# %%
# concat dfs in token_dfs into a single dataframe
swaps_df = pd.concat(df_list, axis=0, ignore_index=True)

# %%
swaps_df
# Out:
#                                                                    swaps_id                                                          swaps_hash  swaps_logIndex                           swaps_protocol_id                                    swaps_to                                  swaps_from  swaps_blockNumber  swaps_timestamp                            swaps_tokenIn_id                  swaps_amountIn  swaps_amountInUSD                           swaps_tokenOut_id           swaps_amountOut  swaps_amountOutUSD                               swaps_pool_id                                                                 endpoint swaps_transaction_id swaps_pair_id swaps_sender  swaps_amount0In  swaps_amount1In  swaps_amount0Out  swaps_amount1Out  swaps_amountUSD
# 0    0x000001eb5c6886fce53a34496e77cfd6ff0699ce6134c445769360f3f74e8308-135  0x000001eb5c6886fce53a34496e77cfd6ff0699ce6134c445769360f3f74e8308             135  0xc0aee478e3658e2610c5f7a4a2e1777ce9e4f2ac  0x63bc843b9640c4d79d6ae0105bc39f773172d121  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f        11583201.00       1609699012  0x368b3a58b5f49392e5c9e4c998cb0bb966752e51            43541759525187090470            4857.77  0xdac17f958d2ee523a2206206994597c13d831ec7                4844750727             4844.75  0xc9cb53b48a2f3a9e75982685644c1870f1405ccb       https://api.thegraph.com/subgraphs/name/messari/sushiswap-ethereum                  NaN           NaN          NaN              NaN              NaN               NaN               NaN              NaN
# 1      0x000002c955f56e44cf032f6615a697e6644e27e91cf047a4ad9b14dd78071695-9  0x000002c955f56e44cf032f6615a697e6644e27e91cf047a4ad9b14dd78071695               9  0xc0aee478e3658e2610c5f7a4a2e1777ce9e4f2ac  0x313e1e91a38615d163a42fc4d6035fbdf5066a99  0x313e1e91a38615d163a42fc4d6035fbdf5066a99        13788443.00       1639287128  0x8689d850cdf3b74a1f6a5eb60302c785b71c2fc7  133562515745942629981287715955            1249.76  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
0x2260fac5e5542a773aa44fbcfedf7c193bc2c599                        21458280            8441.79  0x8daebade922df735c38c80c7ebd708af50815faa        206882096383095413             8224.45  0x4f6a43ad7cba042606decaca730d4ce0a57ac62e  https://api.thegraph.com/subgraphs/name/messari/saddle-finance-ethereum                  NaN           NaN          NaN              NaN              NaN               NaN               NaN              NaN
# 597  0x01641e3b26bd04dd57bc098f17fafc6c437e74064ffe98fa95fe3ca64572c2f5-145  0x01641e3b26bd04dd57bc098f17fafc6c437e74064ffe98fa95fe3ca64572c2f5             145  0x5bdb37d0ddea3a90f233c7b7f6b9394b6b2eef34  0x071fcdd8f8dbab01b864e2abd3d53c55edb86fb8  0x071fcdd8f8dbab01b864e2abd3d53c55edb86fb8        12534895.00       1622366880  0xdac17f958d2ee523a2206206994597c13d831ec7                        12221764              12.22  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48                  12220698               12.22  0x3911f80530595fbd01ab1516ab61255d75aeb066  https://api.thegraph.com/subgraphs/name/messari/saddle-finance-ethereum                  NaN           NaN          NaN              NaN              NaN               NaN               NaN              NaN
# 598   0x0165babb4b096f8d337a89542dee22de8d7b2103988bfeb7ff42f2d59c09be97-16  0x0165babb4b096f8d337a89542dee22de8d7b2103988bfeb7ff42f2d59c09be97              16  0x5bdb37d0ddea3a90f233c7b7f6b9394b6b2eef34  0xeef86c2e49e11345f1a693675df9a38f7d880c8f  0xeef86c2e49e11345f1a693675df9a38f7d880c8f        14904063.00       1654358456  0xbc6da0fe9ad5f3b0d58160288917aa56653660e9        466193293921084228355149          466193.29  0x956f47f50a910163d8bf957cf5846d573e7f87ca  466044112138225220461894           466044.11  0xc69ddcd4dfef25d8a793241834d4cc4b3668ead6  https://api.thegraph.com/subgraphs/name/messari/saddle-finance-ethereum                  NaN           NaN          NaN              NaN              NaN               NaN               NaN              NaN
# 599  0x0169146b14fa0038dad1f81a2dd1eb1f7a57426243ca0673fbcf6c9c6d03f3d6-166  0x0169146b14fa0038dad1f81a2dd1eb1f7a57426243ca0673fbcf6c9c6d03f3d6             166  0x5bdb37d0ddea3a90f233c7b7f6b9394b6b2eef34  0xf82800b8d4ae5579b77e9ed9c31134ee98e2968b  0xf82800b8d4ae5579b77e9ed9c31134ee98e2968b        13255541.00       1632046431  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2             3943348672600107328           13526.39  0x0100546f2cd4c9d97f798ffc9755e47865ff7ee6       3949484039714137874            13547.43  0xa6018520eaacc06c30ff2e1b3ee2c7c22e64196a  https://api.thegraph.com/subgraphs/name/messari/saddle-finance-ethereum                  NaN           NaN          NaN              NaN              NaN               NaN               NaN              NaN
#
# [600 rows x 24 columns]

# %%
# get largest swaps_amountUSD for each endpoint. Display in non-scientific notation
pd.options.display.float_format = '{:.2f}'.format
swaps_df.groupby('endpoint')['swaps_amountInUSD'].max()
# Out:
# endpoint
# https://api.thegraph.com/subgraphs/name/messari/balancer-v2-ethereum       747807.59
# https://api.thegraph.com/subgraphs/name/messari/curve-finance-ethereum    3001788.48
# https://api.thegraph.com/subgraphs/name/messari/saddle-finance-ethereum   1023997.06
# https://api.thegraph.com/subgraphs/name/messari/sushiswap-ethereum         996682.20
# https://api.thegraph.com/subgraphs/name/messari/uniswap-v3-ethereum        603033.64
# https://api.thegraph.com/subgraphs/name/uniswap/uniswap-v2                       NaN
# Name: swaps_amountInUSD, dtype: float64
