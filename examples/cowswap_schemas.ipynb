# %%
# !pip install git+https://github.com/Evan-Kim2028/DataStreams.git
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting git+https://github.com/Evan-Kim2028/DataStreams.git
#   Cloning https://github.com/Evan-Kim2028/DataStreams.git to /tmp/pip-req-build-2dd6zoq4
#   Running command git clone --filter=blob:none --quiet https://github.com/Evan-Kim2028/DataStreams.git /tmp/pip-req-build-2dd6zoq4
#   Resolved https://github.com/Evan-Kim2028/DataStreams.git to commit ed97dc013cce54bb24206f45d29efe5f3b48cd90
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: subgrounds>=1.0.3 in /home/evan/.local/lib/python3.10/site-packages (from DataStreams==0.0.post1.dev46+ged97dc0) (1.0.3)
# Requirement already satisfied: pandas>=1.5.0 in /home/evan/.local/lib/python3.10/site-packages (from DataStreams==0.0.post1.dev46+ged97dc0) (1.5.0)
# Requirement already satisfied: numpy>=1.21.0 in /home/evan/.local/lib/python3.10/site-packages (from pandas>=1.5.0->DataStreams==0.0.post1.dev46+ged97dc0) (1.23.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/evan/.local/lib/python3.10/site-packages (from pandas>=1.5.0->DataStreams==0.0.post1.dev46+ged97dc0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/evan/.local/lib/python3.10/site-packages (from pandas>=1.5.0->DataStreams==0.0.post1.dev46+ged97dc0) (2021.3)
# Requirement already satisfied: pipe<3.0,>=2.0 in /home/evan/.local/lib/python3.10/site-packages (from subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (2.0)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.2 in /home/evan/.local/lib/python3.10/site-packages (from subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (1.10.2)
# Requirement already satisfied: pathlib<2.0.0,>=1.0.1 in /home/evan/.local/lib/python3.10/site-packages (from subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (1.0.1)
# Requirement already satisfied: requests<3.0.0,>=2.27.1 in /home/evan/.local/lib/python3.10/site-packages (from subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (2.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/evan/.local/lib/python3.10/site-packages (from pydantic<2.0.0,>=1.10.2->subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (4.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.5.0->DataStreams==0.0.post1.dev46+ged97dc0) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/evan/.local/lib/python3.10/site-packages (from requests<3.0.0,>=2.27.1->subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (2.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.27.1->subgrounds>=1.0.3->DataStreams==0.0.post1.dev46+ged97dc0) (1.26.9)
# Building wheels for collected packages: DataStreams
#   Building wheel for DataStreams (pyproject.toml) ... done
#   Created wheel for DataStreams: filename=DataStreams-0.0.post1.dev46+ged97dc0-py3-none-any.whl size=7295 sha256=7106c24b88030f6cafac66adaeeb2e8dfdea101d86f3630b22f021d5215063f4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6tuhod0p/wheels/06/e7/63/91de055318e05be20cb8ce687f960fcb1ae3a9e77f754cda6c
# Successfully built DataStreams
# Installing collected packages: DataStreams
#   Attempting uninstall: DataStreams
#     Found existing installation: DataStreams 0.0.post1.dev38+g5abc707
#     Uninstalling DataStreams-0.0.post1.dev38+g5abc707:
#       Successfully uninstalled DataStreams-0.0.post1.dev38+g5abc707
# Successfully installed DataStreams-0.0.post1.dev46+ged97dc0

# %%
import os
import pandas as pd

from datastreams.datastream import Streamer

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)
pd.set_option('max_colwidth', None)

# %%
endpoint = 'https://api.thegraph.com/subgraphs/name/cowprotocol/cow'
# endpoint = 'https://api.thegraph.com/subgraphs/name/messari/uniswap-v3-arbitrum'

# %%
ds = Streamer(endpoint)

# %%
# Search for queryable fields in queryDict, which has a format {str: FieldPath}
ds.queryDict
# Out:
# {'users': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['users']),
#  'tokens': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['tokens']),
#  'orders': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['orders']),
#  'trades': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['trades']),
#  'settlements': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['settlements']),
#  'bundles': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['bundles']),
#  'uniswapPools': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['uniswapPools']),
#  'uniswapTokens': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['uniswapTokens']),
#  'totals': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['totals']),
#  'dailyTotals': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['dailyTotals']),
#  'hourlyTotals': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['hourlyTotals']),
#  'tokenDailyTotals': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['tokenDailyTotals']),
#  'tokenHourlyTotals': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['tokenHourlyTotals']),
#  'tokenTradingEvents': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['tokenTradingEvents']),
#  'pairs': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['pairs']),
#  'pairDailies': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['pairDailies']),
#  'pairHourlies': FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['pairHourlies'])}

# %%
# define deired schemas to query as strings.
my_keys = ['trades', 'orders', 'settlements', 'tokens']

# look up string values to get respective FieldPaths
selected_values = [ds.queryDict.get(key) for key in my_keys]

# %%
print(f'\n\nselected field values: {selected_values}, \ntype: {type(selected_values[0])}')
# Out:
# selected field values: [FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['trades']), FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['orders']), FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['settlements']), FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['tokens'])],
# type: <class 'subgrounds.subgraph.fieldpath.FieldPath'>

# %%
query_path = ds.queryDict.get('tokens')
query_path
# Out:
# FieldPath(https://api.thegraph.com/subgraphs/name/cowprotocol/cow, Query, ['tokens'])

# %% [markdown]
# ### Execute a single query with runQuery()

# %%
# Run a single query on the "trades" schema
df = ds.runQuery(ds.queryFields[3], query_size=150)
df
# Out:
# FIELD - trades
#                                                                                                                                                                                     trades_id  trades_timestamp  trades_gasPrice       trades_feeAmount                                                       trades_txHash                                                trades_settlement_id           trades_buyAmount         trades_sellAmount                         trades_sellToken_id                          trades_buyToken_id                                                                                                     trades_order_id  trades_buyAmountEth  trades_sellAmountEth  trades_buyAmountUsd  trades_sellAmountUsd
# 0    0x000050299d2697ae6d93d9ccec7b55dbe79c920596927402db5784e8e7ef1c9d961eed3b7d4b7c261ee5b023e5f857af5af1e700632d3cf0|0x0454b81f9e497fe91fc2df0e1e7420b9a5e20439b065132daab91c09de8512cf|59        1663907363       6062637482                1344622  0x0454b81f9e497fe91fc2df0e1e7420b9a5e20439b065132daab91c09de8512cf  0x0454b81f9e497fe91fc2df0e1e7420b9a5e20439b065132daab91c09de8512cf      917011543008284856417                4093394367  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48  0x3432b6a60d23ca0dfca7761b7ab56459d9c964d0  0x000050299d2697ae6d93d9ccec7b55dbe79c920596927402db5784e8e7ef1c9d961eed3b7d4b7c261ee5b023e5f857af5af1e700632d3cf0             3.047480              3.049075          4087.560206           4093.394367
# 1     0x0000543dbe9253542d4c3020c5ed40fefd3520dcf5ea9c16e71d611031629c50a85f11d4d6119848a0d2b2b8e270a6846383f39f6199100a|0x8ed73664124b6683be7064af365ce972679b94964680ccb79056ed5192e1a9af|1        1637419389      96392802490       7508432409899440  0x8ed73664124b6683be7064af365ce972679b94964680ccb79056ed5192e1a9af  0x8ed73664124b6683be7064af365ce972679b94964680ccb79056ed5192e1a9af                   20887903       5403161965640052848  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
0x2260fac5e5542a773aa44fbcfedf7c193bc2c599  0x000f1d4ec82ffd26c29c89d8c186147e556ee70f31d860f9fb330cabb3a5779619282e37b5319727501e9577d79dbcdf438038836293faca            48.987198             49.406383         88659.071212          89417.730408
#
# [100 rows x 15 columns]

# %% [markdown]
# ### Firehose Schema Query
#
# Query ALL schema query fields with runStreamerLoop(). Returns a list[DataFrame]

# %%
df_data_list = ds.runStreamerLoop(query_size=777)
# Out:
# FIELD - users
# FIELD - tokens
# FIELD - orders
# FIELD - trades
# FIELD - settlements
# FIELD - bundles
# FIELD - uniswapPools
# FIELD - uniswapTokens
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.local/lib/python3.10/site-packages/simplejson/__init__.py:525, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     521 if (cls is None and encoding is None and object_hook is None and
#     522         parse_int is None and parse_float is None and
#     523         parse_constant is None and object_pairs_hook is None
#     524         and not use_decimal and not kw):
# --> 525     return _default_decoder.decode(s)
#     526 if cls is None:
#
# File ~/.local/lib/python3.10/site-packages/simplejson/decoder.py:370, in JSONDecoder.decode(self, s, _w, _PY3)
#     369     s = str(s, self.encoding)
# --> 370 obj, end = self.raw_decode(s)
#     371 end = _w(s, end).end()
#
# File ~/.local/lib/python3.10/site-packages/simplejson/decoder.py:400, in JSONDecoder.raw_decode(self, s, idx, _w, _PY3)
#     399         idx += 3
# --> 400 return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/subgrounds/pagination/pagination.py:79, in paginate(schema, doc, pagination_strategy)
#      78 try:
# ---> 79   page_data = client.query(
#      80     url=doc.url,
#      81     query_str=doc.graphql,
#      82     variables=doc.variables | args
#      83   )
#      84   data = merge(data, page_data)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/client.py:162, in query(url, query_str, variables)
#     151 logger.info(
#     152   f'client.query: url = {url}, variables = {variables}\n{query_str}'
#     153 )
#     154 resp = requests.post(
#     155   url,
#     156   json=(
#     157     {'query': query_str}
#     158     if variables == {}
#     159     else {'query': query_str, 'variables': variables}
#     160   ),
#     161   headers={'Content-Type': 'application/json'}
# --> 162 ).json()
#     164 try:
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# PaginationError                           Traceback (most recent call last)
# /home/evan/Documents/github/DataStreams/examples/cowswap_schema_firehose.ipynb Cell 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/evan/Documents/github/DataStreams/examples/cowswap_schema_firehose.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> df_data_list = ds.runStreamerLoop(query_size=777)
#
# File ~/.local/lib/python3.10/site-packages/datastreams/streamer.py:147, in Streamer.runStreamerLoop(self, query_size)
#     145 start_time = time.time()
#     146 for i in range(len(self.queryFields)):
# --> 147     df = self.runQuery(self.queryFields[i], query_size)
#     148     df_data.append(df)
#     149 # end time
#
# File ~/.local/lib/python3.10/site-packages/datastreams/streamer.py:128, in Streamer.runQuery(self, query_field, query_size)
#     125 print(f'FIELD - {query_field}')
#     127 # 2) Run query
# --> 128 df = self.sub.query_df(query_field(first=query_size))
#     130 return df
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:380, in Subgrounds.query_df(self, fpaths, columns, concat, pagination_strategy)
#     309 """Same as :func:`Subgrounds.query` but formats the response data into a
#     310 Pandas DataFrame. If the response data cannot be flattened to a single query
#     311 (e.g.: when querying multiple list fields that return different entities),
#    (...)
#     372     9       1643213196  2610.686563
#     373 """
#     374 fpaths = list(
#     375   [fpaths]
#     376   | traverse
#     377   | map(FieldPath._auto_select)
#     378   | traverse
#     379 )
# --> 380 json_data = self.query_json(fpaths, pagination_strategy=pagination_strategy)
#     381 return df_of_json(json_data, fpaths, columns, concat)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:274, in Subgrounds.query_json(self, fpaths, pagination_strategy)
#     267 fpaths = list(
#     268   [fpaths]
#     269   | traverse
#     270   | map(FieldPath._auto_select)
#     271   | traverse
#     272 )
#     273 req = self.mk_request(fpaths)
# --> 274 return self.execute(req, pagination_strategy=pagination_strategy)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:199, in Subgrounds.execute(self, req, pagination_strategy)
#     189   match transforms:
#     190     case []:
#     191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#    (...)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False  # Suppress mypy missing return statement warning
# --> 199 return transform_req(self.global_transforms, req)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:191, in Subgrounds.execute.<locals>.transform_req(transforms, req)
#     188 def transform_req(transforms: list[RequestTransform], req: DataRequest) -> list[dict]:
#     189   match transforms:
#     190     case []:
# --> 191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#     192     case [transform, *rest]:
#     193       new_req = transform.transform_request(req)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:191, in Subgrounds.execute.<locals>.transform_req.<locals>.<lambda>(doc)
#     188 def transform_req(transforms: list[RequestTransform], req: DataRequest) -> list[dict]:
#     189   match transforms:
#     190     case []:
# --> 191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#     192     case [transform, *rest]:
#     193       new_req = transform.transform_request(req)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:183, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
#     180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
# --> 183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:183, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
#     180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
# --> 183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:180, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
# --> 180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
#     183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:172, in Subgrounds.execute.<locals>.execute_document(doc)
#     167 subgraph: Subgraph = next(
#     168   self.subgraphs.values()
#     169   | where(lambda sg: sg._url == doc.url)
#     170 )
#     171 if pagination_strategy is not None and subgraph._is_subgraph:
# --> 172   return paginate(subgraph._schema, doc, pagination_strategy=pagination_strategy)
#     173 else:
#     174   return client.query(doc.url, doc.graphql, variables=doc.variables)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/pagination/pagination.py:89, in paginate(schema, doc, pagination_strategy)
#      87       break
#      88     except Exception as exn:
# ---> 89       raise PaginationError(exn.args[0], strategy)
#      91   return data
#      93 except SkipPagination:
#
# PaginationError: Expecting value: line 1 column 1 (char 0)

# %%
df_data_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/evan/Documents/github/DataStreams/examples/cowswap_schema_firehose.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/evan/Documents/github/DataStreams/examples/cowswap_schema_firehose.ipynb#X24sZmlsZQ%3D%3D?line=0'>1</a> df_data_list
#
# NameError: name 'df_data_list' is not defined

# %%
# swaps is # 6 - uniswapPools
df_data_list[6]
# Out:
#                               uniswapPools_id                      uniswapPools_token0_id                      uniswapPools_token1_id uniswapPools_liquidity  uniswapPools_token0Price  uniswapPools_token1Price  uniswapPools_tick  uniswapPools_totalValueLockedToken0  uniswapPools_totalValueLockedToken1
# 0  0x0001fcbba8eb491c3ccfeddc5a5caba1a98c4c28  0xbef81556ef066ec840a540595c8d12f516b6378f  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  303015134493562686441              1.000164e+04              9.998356e-05           -92110.0                         30001.000000                         1.365552e-02
# 1  0x0002e63328169d7feea121f1e32e4f620abf0352  0x0d438f3b5175bebc262bf23753c1e53d03432bde  0x903bef1736cddf2a537176cf3c64579c3867a881      15673931107413316              3.241364e-01              3.085121e+00          -195977.0                           936.948476                         3.427675e+03
# 2  0x0003c9d75e102b8a9fe77280ca410e9135beb150  0x4c3ec62103417a31064e5c23c24c22ee611c4911  0xdac17f958d2ee523a2206206994597c13d831ec7                      0              2.938957e-41              3.402568e+40           887271.0                             0.010000                         1.766928e+01
# 3  0x000ea4a83acefdd62b1b43e9ccc281f442651520  0x4fabb145d64652a948d72533023f6e7a623c7c53  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  134336871887766194967              1.607574e+03              6.220552e-04           -73829.0                          9336.248877                         3.516403e+00
# 4  0x000f0c0b0b791e855dcc5ad6501c7529dea882e0  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  0xd1063ee5ec2891991a29fefb52bcc448cd386844                      0              0.000000e+00              0.000000e+00                NaN                             0.002200                         1.100000e+10
# 5  0x0025ade782cc2b2415d1e841a8d52ff5dce33dfe  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  0xea5b19c073f8074f9a8dcd693d01b6acb1c26ae4  292918389273214376584              2.382009e-08              4.198137e+07           175536.0                             1.265986                         2.064900e+08
# 6  0x002c0b78c8057636918b963cd26c07b7f2892bd8  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  0xc66b1f449e43c2356707431d38b87ca9c46bbfc1                      0              3.402568e+38              2.938957e-39          -887272.0                             0.001411                         1.000000e-18
# 7  0x00323a300261042dd5d697e3f92a06279cc7d15b  0x7ed4029d5b7ab05baf4516e1aad57dfc8265e223  0x9c405acf8688afb61b3197421cdeec1a266c6839                      0              3.402568e+38              2.938957e-39          -887272.0                          2883.303368                         5.178269e+03
# 8  0x0041426a64a85ef884387dc3a69f9df1fbb7f9d1  0xa00055e6ee4d1f4169096ecb682f70caa8c29987  0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48                      0              3.402568e+26              2.938957e-27          -887272.0                         31926.383094                         1.000000e-06
# 9  0x005843e075e77ba46a26d24914db10a4d9ca0122  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  0xfb83708c7d2b6ef19177d9b2a8db0b4cbf1d7687                      0              1.744042e-13              5.733808e+12           293788.0                             0.000068                         6.000000e-18

# %% [markdown]
# ### Parallelized Firehose Query

# %%
# runStreamerLoopParallel() uses the standard python library concurrent to execute parallel queries. Observed speedup is around 2x
df_data_list_parallel = ds.runStreamerLoopParallel(query_list=ds.queryFields, query_size=777)
# Out:
# FIELD - users
# FIELD - tokens
# FIELD - orders
# FIELD - trades
# FIELD - settlements
# FIELD - bundles
# FIELD - uniswapPools
# sys:1: ResourceWarning: unclosed socket <zmq.Socket(zmq.PUSH) at 0x7fa00e00d720>
# ResourceWarning: Enable tracemalloc to get the object allocation traceback
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/models.py:971, in Response.json(self, **kwargs)
#     970 try:
# --> 971     return complexjson.loads(self.text, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
#
# File ~/.local/lib/python3.10/site-packages/simplejson/__init__.py:525, in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, use_decimal, **kw)
#     521 if (cls is None and encoding is None and object_hook is None and
#     522         parse_int is None and parse_float is None and
#     523         parse_constant is None and object_pairs_hook is None
#     524         and not use_decimal and not kw):
# --> 525     return _default_decoder.decode(s)
#     526 if cls is None:
#
# File ~/.local/lib/python3.10/site-packages/simplejson/decoder.py:370, in JSONDecoder.decode(self, s, _w, _PY3)
#     369     s = str(s, self.encoding)
# --> 370 obj, end = self.raw_decode(s)
#     371 end = _w(s, end).end()
#
# File ~/.local/lib/python3.10/site-packages/simplejson/decoder.py:400, in JSONDecoder.raw_decode(self, s, idx, _w, _PY3)
#     399         idx += 3
# --> 400 return self.scan_once(s, idx=_w(s, idx).end())
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# JSONDecodeError                           Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/subgrounds/pagination/pagination.py:79, in paginate(schema, doc, pagination_strategy)
#      78 try:
# ---> 79   page_data = client.query(
#      80     url=doc.url,
#      81     query_str=doc.graphql,
#      82     variables=doc.variables | args
#      83   )
#      84   data = merge(data, page_data)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/client.py:162, in query(url, query_str, variables)
#     151 logger.info(
#     152   f'client.query: url = {url}, variables = {variables}\n{query_str}'
#     153 )
#     154 resp = requests.post(
#     155   url,
#     156   json=(
#     157     {'query': query_str}
#     158     if variables == {}
#     159     else {'query': query_str, 'variables': variables}
#     160   ),
#     161   headers={'Content-Type': 'application/json'}
# --> 162 ).json()
#     164 try:
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:975, in Response.json(self, **kwargs)
#     972 except JSONDecodeError as e:
#     973     # Catch JSON-related errors and raise as requests.JSONDecodeError
#     974     # This aliases json.JSONDecodeError and simplejson.JSONDecodeError
# --> 975     raise RequestsJSONDecodeError(e.msg, e.doc, e.pos)
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)
#
# During handling of the above exception, another exception occurred:
#
# PaginationError                           Traceback (most recent call last)
# /home/evan/Documents/github/DataStreams/examples/cowswap_schema_firehose.ipynb Cell 14 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/home/evan/Documents/github/DataStreams/examples/cowswap_schema_firehose.ipynb#X12sZmlsZQ%3D%3D?line=0'>1</a> # runStreamerLoopParallel() uses the standard python library concurrent to execute parallel queries. Observed speedup is around 2x
# ----> <a href='vscode-notebook-cell:/home/evan/Documents/github/DataStreams/examples/cowswap_schema_firehose.ipynb#X12sZmlsZQ%3D%3D?line=1'>2</a> df_data_list_parallel = ds.runStreamerLoopParallel(query_list=ds.queryFields, query_size=777)
#
# File ~/.local/lib/python3.10/site-packages/datastreams/streamer.py:173, in Streamer.runStreamerLoopParallel(self, query_list, query_size, cores)
#     171     for args in query_list:
#     172         future = executor.submit(self.runQuery, *args)
# --> 173         df_data.append(future.result())
#     175 end_time = time.time() - start_time
#     176 print(f'{len(self.queryFields)} queries, parallelized 8 cores: {end_time:.2f} seconds. Largest df is {len(max(df_data, key=len))}\n')
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File /usr/lib/python3.10/concurrent/futures/thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# File ~/.local/lib/python3.10/site-packages/datastreams/streamer.py:128, in Streamer.runQuery(self, query_field, query_size)
#     125 print(f'FIELD - {query_field}')
#     127 # 2) Run query
# --> 128 df = self.sub.query_df(query_field(first=query_size))
#     130 return df
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:380, in Subgrounds.query_df(self, fpaths, columns, concat, pagination_strategy)
#     309 """Same as :func:`Subgrounds.query` but formats the response data into a
#     310 Pandas DataFrame. If the response data cannot be flattened to a single query
#     311 (e.g.: when querying multiple list fields that return different entities),
#    (...)
#     372     9       1643213196  2610.686563
#     373 """
#     374 fpaths = list(
#     375   [fpaths]
#     376   | traverse
#     377   | map(FieldPath._auto_select)
#     378   | traverse
#     379 )
# --> 380 json_data = self.query_json(fpaths, pagination_strategy=pagination_strategy)
#     381 return df_of_json(json_data, fpaths, columns, concat)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:274, in Subgrounds.query_json(self, fpaths, pagination_strategy)
#     267 fpaths = list(
#     268   [fpaths]
#     269   | traverse
#     270   | map(FieldPath._auto_select)
#     271   | traverse
#     272 )
#     273 req = self.mk_request(fpaths)
# --> 274 return self.execute(req, pagination_strategy=pagination_strategy)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:199, in Subgrounds.execute(self, req, pagination_strategy)
#     189   match transforms:
#     190     case []:
#     191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#    (...)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False  # Suppress mypy missing return statement warning
# --> 199 return transform_req(self.global_transforms, req)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:191, in Subgrounds.execute.<locals>.transform_req(transforms, req)
#     188 def transform_req(transforms: list[RequestTransform], req: DataRequest) -> list[dict]:
#     189   match transforms:
#     190     case []:
# --> 191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#     192     case [transform, *rest]:
#     193       new_req = transform.transform_request(req)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:191, in Subgrounds.execute.<locals>.transform_req.<locals>.<lambda>(doc)
#     188 def transform_req(transforms: list[RequestTransform], req: DataRequest) -> list[dict]:
#     189   match transforms:
#     190     case []:
# --> 191       return list(req.documents | map(lambda doc: transform_doc(self.subgraphs[doc.url]._transforms, doc)))
#     192     case [transform, *rest]:
#     193       new_req = transform.transform_request(req)
#     194       data = transform_req(rest, new_req)
#     195       return transform.transform_response(req, data)
#     197   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:183, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
#     180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
# --> 183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:183, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
#     180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
# --> 183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:180, in Subgrounds.execute.<locals>.transform_doc(transforms, doc)
#     176 def transform_doc(transforms: list[DocumentTransform], doc: Document) -> dict:
#     177   logger.debug(f'execute.transform_doc: doc = \n{doc.graphql}')
#     178   match transforms:
#     179     case []:
# --> 180       return execute_document(doc)
#     181     case [transform, *rest]:
#     182       new_doc = transform.transform_document(doc)
#     183       data = transform_doc(rest, new_doc)
#     184       return transform.transform_response(doc, data)
#     186   assert False
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/subgrounds.py:172, in Subgrounds.execute.<locals>.execute_document(doc)
#     167 subgraph: Subgraph = next(
#     168   self.subgraphs.values()
#     169   | where(lambda sg: sg._url == doc.url)
#     170 )
#     171 if pagination_strategy is not None and subgraph._is_subgraph:
# --> 172   return paginate(subgraph._schema, doc, pagination_strategy=pagination_strategy)
#     173 else:
#     174   return client.query(doc.url, doc.graphql, variables=doc.variables)
#
# File ~/.local/lib/python3.10/site-packages/subgrounds/pagination/pagination.py:89, in paginate(schema, doc, pagination_strategy)
#      87       break
#      88     except Exception as exn:
# ---> 89       raise PaginationError(exn.args[0], strategy)
#      91   return data
#      93 except SkipPagination:
#
# PaginationError: Expecting value: line 1 column 1 (char 0)

# %%
df_data_list_parallel[6]
# Out:
